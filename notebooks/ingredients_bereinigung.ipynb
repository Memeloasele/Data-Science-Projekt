# %%
import sys
print(sys.executable)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import warnings
warnings.filterwarnings("ignore")

# ── 0. DATEI LADEN ───────────────────────────────────────────
# Pfad anpassen!
CSV_PATH = "../en.openfoodfacts.org.products 2.csv"

cols = ["ingredients_text", "ingredients_tags", "ingredients_analysis_tags"]
df = pd.read_csv(CSV_PATH, sep="	", usecols=cols, low_memory=False)

# Füllrate aller Spalten
print(df[cols].notna().mean().round(2) * 100)

# Alle Paare auf Überlappung prüfen
import itertools

for col1, col2 in itertools.combinations(cols, 2):
    beide = df[[col1, col2]].notna().all(axis=1).sum()
    print(f"{col1} + {col2}: beide befüllt in {beide} Zeilen")

# Zeilen wo mehrere Spalten gleichzeitig befüllt sind
mask = df[cols].notna().sum(axis=1) >= 2
df[cols][mask].head(50)

import pandas as pd
# Paarweise Überlappung aller 4 Spalten (wie oft sind je 2 gleichzeitig befüllt?)
overlap = pd.DataFrame(index=cols, columns=cols, dtype=float)
for c1 in cols:
    for c2 in cols:
        overlap.loc[c1, c2] = df[[c1, c2]].notna().all(axis=1).sum()
overlap.astype(int)
# Out:
# /opt/homebrew/opt/python@3.11/bin/python3.11
# ingredients_text             28.0
# ingredients_tags             28.0
# ingredients_analysis_tags    30.0
# dtype: float64
# ingredients_text + ingredients_tags: beide befüllt in 1277688 Zeilen
# ingredients_text + ingredients_analysis_tags: beide befüllt in 1278209 Zeilen
# ingredients_tags + ingredients_analysis_tags: beide befüllt in 1277667 Zeilen
#                            ingredients_text  ingredients_tags  \
# ingredients_text                    1280988           1277688
# ingredients_tags                    1277688           1277700
# ingredients_analysis_tags           1278209           1277667
#
#                            ingredients_analysis_tags
# ingredients_text                             1278209
# ingredients_tags                             1277667
# ingredients_analysis_tags                    1356189

# %%
# Zeilen wo mehrere Spalten gleichzeitig befüllt sind
mask = df[cols].notna().sum(axis=1) >= 2
df[cols][mask].head(20)
# Out:
#                                      ingredients_text  \
# 1   Weizenmehl, Rapsöl, Speisesalz, 1,7% Meersalz,...
# 4   Thiamin, Biotin, Chromium, Garcinia cambogia f...
# 12  HONIG stillende Frauen nicht geeignet. D bestr...
# 13  Sojaproteinisolat, Weizen - protein, Kaffee-Ex...
# 15  Farine de blé 33%, sucre, huile de colza, œufs...
# 18  Water, Leptospermum Scoparium Mel (Manuka Hone...
# 19  Farine de blé 27%, chocolat au lait 18% (sucre...
# 20                                         Beef liver
# 21  whey protein concentrate, milk protein concent...
# 24  Nuts (Peanuts, Almonds), Prebiotic Blend (Tapi...
# 25       Inulin Prebiotic Fiber (Chicory Root Powder)
# 26  Madeleines ChocoNoir - Madeleines nappées de c...
# 28  Pommes séchées - Dried Apple* Origine: Autrich...
# 29  glucose syrup, sugar, water, pectin, black car...
# 30  beef, seasoning (sugar, garlic, onion, salt, s...
# 31  NIK ODŻYWCZY WSPIERA PRAWIDŁOWE FUNKCJONOWANIE...
# 32  Organic Defatted Hemp Seed Powder. Certified O...
